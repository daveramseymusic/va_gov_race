# %% [markdown]
# # Import A Table From Real Clear Politics and Convert to CSV

# %%
# pip install bs4
# !pip install lxml
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.realclearpolitics.com/epolls/2021/governor/va/virginia_governor_youngkin_vs_mcauliffe-7373.html'

# %%
# create 'headers' and use them in your 'requests' 
# create a header so the website thinks this is a web-browser
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'} # This is chrome, you can set whatever browser you like
# save your response
r = requests.get(url, headers=headers)

print(r.status_code)
print(r.url)
# Out:
# 200
# https://www.realclearpolitics.com/epolls/2021/governor/va/virginia_governor_youngkin_vs_mcauliffe-7373.html

# %%
#save soup
soup = BeautifulSoup(r.text, 'html.parser')

#grab all tables 
tables = soup.find_all('table', class_ = "data large")
#only use the second table 'table[1]'
table = tables[1]

# %%
# create a list of rows and turn this list into a df
tlist = []
for tr in table.find_all('tr'): 
    td = tr.find_all('td') 
    
    # get the info from the header for labels
    if len(tr.find_all('th')) != 0:
        row = [i.text for i in tr.find_all('th')]
    else:
        row = [i.text for i in td] #turn each row'sinfo into a list of info
    tlist.append(row)
    
#create df using first entry in tlist as column header
df = pd.DataFrame(tlist[1:],columns=tlist[0])  
df.head(3)
# Out:
#                            Poll           Date   Sample  MoE Youngkin (R)  \
# 0                 Final Results             --       --   --         50.6
# 1                   RCP Average  10/20 - 10/31       --   --         48.5
# 2  Trafalgar Group (R)Trafalgar  10/29 - 10/31  1081 LV  3.0           49
#
#   McAuliffe (D)         Spread
# 0          48.7  Youngkin +1.9
# 1          46.8  Youngkin +1.7
# 2            47    Youngkin +2

# %%
# save to csv
df.to_csv('va_gov_real_clear_all_polls.csv',index=False)

# %%
df = pd.read_csv('va_gov_real_clear_all_polls.csv')
df
# Out:
#                                                  Poll           Date   Sample  \
# 0                                       Final Results             --       --
# 1                                         RCP Average  10/20 - 10/31       --
# 2                        Trafalgar Group (R)Trafalgar  10/29 - 10/31  1081 LV
# 3          FOX 5 DC/InsiderAdvantage*InsiderAdvantage  10/27 - 10/30   500 LV
# 4                                    FOX NewsFOX News  10/24 - 10/27  1212 LV
# 5                    Washington Post*Washington Post*  10/20 - 10/26   918 LV
# 6                                    Emerson*Emerson*  10/22 - 10/23   875 LV
# 7                        USA Today/Suffolk*USA Today*  10/21 - 10/24   500 LV
# 8                      Christopher Newport Univ.*CNU*  10/17 - 10/25   944 LV
# 9                    Roanoke College*Roanoke College*  10/14 - 10/28   571 LV
# 10                                   MonmouthMonmouth  10/16 - 10/19  1005 RV
# 11                                             VCUVCU   10/9 - 10/21   722 LV
# 12                       Trafalgar Group (R)Trafalgar  10/11 - 10/13  1095 LV
